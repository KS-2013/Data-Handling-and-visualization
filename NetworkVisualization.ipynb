# %% [markdown]
# <a href="https://colab.research.google.com/github/Komal-Sahani-U/Data-Handling-and-visualization/blob/main/NetworkVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install networkx

# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(2,3),(3,4),(5,1)])
pos=nx.spring_layout(G)
nx.draw(G,pos,with_labels=True,node_color='skyblue',node_size=1400,edge_color='black',linewidths=1,font_size=15)
plt.show()
